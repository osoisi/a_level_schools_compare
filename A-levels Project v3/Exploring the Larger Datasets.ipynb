# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\aa1\Desktop\data_repo\a_levels_schools\a_level_schools_compare\England postcodes.csv")
# Out:
# C:\Users\aa1\AppData\Local\Temp\ipykernel_13996\136645907.py:1: DtypeWarning: Columns (18,29,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\aa1\Desktop\data_repo\a_levels_schools\a_level_schools_compare\England postcodes.csv")

# %%
df.describe()
# Out:
#            Latitude     Longitude       Easting      Northing    Population  \
# count  2.254650e+06  2.254650e+06  2.247615e+06  2.247615e+06  1.227684e+06
# mean   5.215691e+01 -1.212772e+00  4.539950e+05  2.701357e+05  4.318093e+01
# std    3.136857e+00  1.229774e+00  8.499630e+04  1.277651e+05  3.897535e+01
# min    0.000000e+00 -6.352647e+00  8.789700e+04  8.132000e+03  1.000000e+00
# 25%    5.144705e+01 -2.115475e+00  3.921555e+05  1.734500e+05  1.500000e+01
# 50%    5.202230e+01 -1.244267e+00  4.506850e+05  2.379760e+05  3.300000e+01
# 75%    5.337906e+01 -1.955682e-01  5.247000e+05  3.873200e+05  6.200000e+01
# max    5.579742e+01  1.762773e+00  6.555950e+05  6.560140e+05  3.215000e+03
#
#          Households      Altitude    London zone  \
# count  1.227684e+06  2.247621e+06  329606.000000
# mean   1.797154e+01  6.492101e+01       3.124103
# std    1.489076e+01  5.196415e+01       1.594836
# min    0.000000e+00 -4.000000e+00       1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2254650 entries, 0 to 2254649
# Data columns (total 58 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   Postcode                             object
#  1   In Use?                              object
#  2   Latitude                             float64
#  3   Longitude                            float64
#  4   Easting                              float64
#  5   Northing                             float64
#  6   Grid Ref                             object
#  7   County                               object
#  8   District                             object
#  9   Ward                                 object
#  10  District Code                        object
#  11  Ward Code                            object
#  12  Country                              object
#  13  County Code                          object
#  14  Constituency                         object
# ...

# %%
df.nunique()
# Out:
# Postcode                               2254650
# In Use?                                      2
# Latitude                               1306832
# Longitude                              1375917
# Easting                                 357914
# Northing                                452698
# Grid Ref                               1020157
# County                                      48
# District                                   296
# Ward                                      6430
# District Code                              296
# Ward Code                                 6862
# Country                                      1
# County Code                                 48
# Constituency                               533
# Introduced                                 351
# Terminated                                 293
# Parish                                    9800
# National Park                               10
# Population                                 666
# ...

# %%
df.isnull().sum()
# Out:
# Postcode                                     0
# In Use?                                      0
# Latitude                                     0
# Longitude                                    0
# Easting                                   7035
# Northing                                  7035
# Grid Ref                                  7035
# County                                    7035
# District                                  7035
# Ward                                      7035
# District Code                             7035
# Ward Code                                 7035
# Country                                      0
# County Code                               7035
# Constituency                              7035
# Introduced                                   0
# Terminated                             1485367
# Parish                                   75699
# National Park                          2232908
# Population                             1026966
# ...

# %%
df2=df[df['In Use?']=='Yes']

# %%
df2.isnull().sum()
# Out:
# Postcode                                     0
# In Use?                                      0
# Latitude                                     0
# Longitude                                    0
# Easting                                    887
# Northing                                   887
# Grid Ref                                   887
# County                                     887
# District                                   887
# Ward                                       887
# District Code                              887
# Ward Code                                  887
# Country                                      0
# County Code                                887
# Constituency                               887
# Introduced                                   0
# Terminated                             1485367
# Parish                                   45976
# National Park                          1468648
# Population                              262259
# ...
